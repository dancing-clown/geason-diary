# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def cv_show(img, name):
    cv2.imshow(name, img)
    cv2.waitKey()
    cv2.destroyAllWindows()

# %%
# 模版匹配
img = cv2.imread("/Users/gaoyicheng/Documents/project/interviews/language/rust/qqsg/vnc_fullscreen_test.png", 0)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
template = cv2.imread("/Users/gaoyicheng/Documents/project/interviews/language/rust/qqsg/vnc_small_region_test.png", 0)
# template_gray = cv2.cvtColor(template, cv2.COLOR_BGR2GRAY)
res = cv2.matchTemplate(img, template, cv2.TM_SQDIFF_NORMED)

# %%
hist = cv2.calcHist([img], [0], None, [256], [0, 256])
hist.shape
# Out:
# (256, 1)

# %%
plt.hist(img.ravel(), 256)
plt.show()

# %% [markdown]
# TM_SQDIFF: 计算平方不同，计算出来的值越小越相关
# TM_CCORR: 计算相关性，计算出来的值越大，越相关
# TM_CCOEFF:计算相关系数，计算出来的值越大，越相关
# TM_SQDIFF_NORMED:计算归一化平方不同，计算的值越接近0，越相关
# TM_CCORR_NORMAED:计算归一化相关性，计算出来的值越接近1，越相关
# TM_CCOEFF_NORMED:计算归一化相关系数，计算出来的值越接近1，越相关
#
# 公式：https://docs.opencv.org/4.12.0/df/dfb/group__imgproc__object.html

# %%
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)

# %%
min_val

# %%
min_loc
# Out:
# (50, 50)
